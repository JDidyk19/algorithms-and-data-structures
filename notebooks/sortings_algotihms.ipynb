# %% [markdown]
# # Sorting Algorithm Comparison

# %%
import matplotlib.pyplot as plt
from scipy.special import gamma
import numpy as np

# %% [markdown]
# ### A graph of the time complexities of different algorithms

# %%
n = np.linspace(1, 10, 1000)
plt.plot(n, n ** 2, label="bubble sort")
plt.plot(n, n + n, label="counting sort")
plt.plot(n, (n + 1) ** 2, label="insertion sort")
plt.plot(n, n * np.log(n), label="merge sort")
plt.plot(n, (n - 1) * np.log(n), label="quick sort")
plt.plot(n, (n - 1) ** 2, label="selection sort")
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### A graph of the time complexity of Bogosort algorithm

# %%
n = np.linspace(1, 10, 1000)
plt.plot(n, n * gamma(n), label="bogosort")
# plt.plot(n, n ** 5, label="bogosort")
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Running time of sorting algorithms

# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\algorithms")
    
from sorting.bubble_sort import bubble_sort
from sorting.counting_sort import counting_sort
from sorting.insertion_sort import insertion_sort
from sorting.merge_sort import merge_sort
from sorting.quick_sort import quick_sort
from sorting.selection_sort import selection_sort
from sorting.bogosort import bogosort

# %%
import random

test_array = np.random.randint(1, 1000, size=1000)
test_array_for_counting = [random.randint(1, 1000) for _ in range(1000)]

# %% [markdown]
# ### Running time of Bubble sort

# %%
# %timeit bubble_sort(test_array)
# Out:
# 104 ms ± 919 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Running time of Counting sort

# %%
# %timeit counting_sort(test_array_for_counting)
# Out:
# 323 µs ± 9.93 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ### Running time of Insertion sort

# %%
# %timeit insertion_sort(test_array)
# Out:
# 363 µs ± 4.83 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ### Running time of Merge sort

# %%
# %timeit merge_sort(test_array)
# Out:
# 4.53 ms ± 119 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### Running time of Quick sort

# %%
# %timeit quick_sort(test_array)
# Out:
# 229 ms ± 3.06 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Running time of Selection sort

# %%
# %timeit selection_sort(test_array)
# Out:
# 102 ms ± 1.46 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### Running time of Bogosort

# %%
test_array = np.random.randint(1, 10, size=5)

# %%
# %timeit bogosort(test_array)
# Out:
# 1.25 µs ± 16.9 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
